# %% [markdown]
# # NeuroLab: Model Training and Evaluation\n\nThis notebook demonstrates the complete model training pipeline for EEG mental state classification.\n\n**Features:**\n- Multiple model architectures (CNN-LSTM, ResNet-LSTM, Transformer)\n- Advanced training techniques (class balancing, regularization, callbacks)\n- Comprehensive evaluation metrics\n- Model comparison and selection\n- Confidence calibration\n\n**Author:** NeuroLab Team  \n**License:** MIT

# %% [markdown]
# ## 1. Setup and Imports

# %%
# System imports\nimport sys\nimport os\nsys.path.append('../')\n\n# Core libraries\nimport numpy as np\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nfrom datetime import datetime\nimport warnings\nimport json\nwarnings.filterwarnings('ignore')\n\n# Machine learning\nimport tensorflow as tf\nfrom sklearn.model_selection import train_test_split\nfrom sklearn.preprocessing import StandardScaler\nfrom sklearn.metrics import classification_report, confusion_matrix\n\n# NeuroLab modules\nfrom src.models.model import train_hybrid_model, evaluate_model, model_comparison\nfrom src.preprocessing.features import extract_features\nfrom src.preprocessing.preprocess import preprocess_data\nfrom src.utils.interpretability import ModelInterpretability\n\n# Set style\nplt.style.use('seaborn-v0_8-darkgrid')\nsns.set_palette(\"husl\")\n\nprint(\"✓ All imports successful\")\nprint(f\"TensorFlow version: {tf.__version__}\")\nprint(f\"GPU Available: {len(tf.config.list_physical_devices('GPU')) > 0}\")

# %% [markdown]
# ## 2. Load and Prepare Data

# %%
# Load the dataset generated in notebook 01\ntry:\n    df = pd.read_csv('eeg_mental_states_dataset.csv')\n    print(f\"✓ Dataset loaded: {len(df)} samples\")\nexcept FileNotFoundError:\n    print(\"❌ Dataset not found. Please run notebook 01 first.\")\n    raise\n\n# Display dataset info\nprint(f\"\\nDataset shape: {df.shape}\")\nprint(f\"Features: {list(df.columns)}\")\nprint(f\"\\nClass distribution:\")\nprint(df['state'].value_counts().sort_index())\n\n# Display first few rows\ndf.head()
